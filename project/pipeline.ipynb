# %% [markdown]
# ## Importing Python Packages

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
import datetime as dt

# %% [markdown]
# ## Loading the 311 Dataset

# %%
df = pd.read_csv('311_Service_Requests_from_2010_to_Present_20241111.csv')
# Out:
# C:\Users\z004ymcy\AppData\Local\Temp\ipykernel_5908\3569116635.py:1: DtypeWarning: Columns (8,17,18,20,31,32,33,34,35,36,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('311_Service_Requests_from_2010_to_Present_20241111.csv')

# %% [markdown]
# ## Preprocessing the 311 Data

# %% [markdown]
# Checking the loaded data

# %%
pd.set_option('display.max_columns', None)
df.head(5)
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    62613972  09/30/2024 03:14:00 PM  09/29/2024 03:13:00 PM    DOT
# 1    62618855  09/30/2024 11:34:12 AM  09/30/2024 11:34:12 AM    DOB
# 2    62608311  09/30/2024 11:31:35 AM  09/30/2024 11:32:06 AM    DPR
# 3    62617195  09/30/2024 11:31:11 AM  09/30/2024 11:31:11 AM    DOB
# 4    62609038  09/30/2024 11:30:15 AM  09/30/2024 11:33:18 AM   NYPD
#
#                           Agency Name                 Complaint Type  \
# 0        Department of Transportation         Street Light Condition
# 1             Department of Buildings                   Building/Use
# 2  Department of Parks and Recreation        Maintenance or Facility
# 3             Department of Buildings  General Construction/Plumbing
# 4     New York City Police Department                  Drug Activity
#
#                                          Descriptor    Location Type  \
# 0                        Multiple St Lts Dayburning              NaN
# 1  Illegal Conversion Of Residential Building/Space              NaN
# 2                                 Garbage or Litter  Street/Curbside
# 3     Cons - Contrary/Beyond Approved Plans/Permits              NaN
# 4                                       Use Outside  Street/Sidewalk
#
#   Incident Zip         Incident Address        Street Name     Cross Street 1  \
# 0      11228.0         DYKER BEACH PARK   DYKER BEACH PARK             14 AVE
# 1      11219.0           1071 65 STREET          65 STREET                NaN
# 2      10457.0             CROTONA PARK       CROTONA PARK  CLAREMONT PARKWAY
# 3      11377.0          41-24 51 STREET          51 STREET                NaN
# 4      11365.0  71-01 PARSONS BOULEVARD  PARSONS BOULEVARD          71 AVENUE
#
#        Cross Street 2 Intersection Street 1 Intersection Street 2  \
# 0               7 AVE                   NaN                   NaN
# 1                 NaN                   NaN                   NaN
# 2  CROTONA PARK NORTH     CLAREMONT PARKWAY    CROTONA PARK NORTH
# 3                 NaN                   NaN                   NaN
# 4           72 AVENUE             71 AVENUE             72 AVENUE
#
#    Address Type           City           Landmark Facility Type   Status  \
# 0     PLACENAME       BROOKLYN                NaN           NaN  Pending
# 1       ADDRESS       BROOKLYN                NaN           NaN     Open
# 2  UNRECOGNIZED          BRONX       CROTONA PARK           NaN   Closed
# 3       ADDRESS       WOODSIDE                NaN           NaN     Open
# 4       ADDRESS  FRESH MEADOWS  PARSONS BOULEVARD           NaN   Closed
#
#   Due Date                             Resolution Description  \
# 0      NaN  Service Request status for this request is ava...
# 1      NaN  Your Service Request has been submitted to the...
# 2      NaN  NYC Parks has completed the requested work ord...
# 3      NaN  Your Service Request has been submitted to the...
# 4      NaN  The Police Department responded to the complai...
#
#   Resolution Action Updated Date Community Board           BBL   Borough  \
# 0         09/29/2024 03:13:00 PM     10 BROOKLYN  3.064180e+09  BROOKLYN
# 1         09/30/2024 12:00:00 AM     10 BROOKLYN  3.057440e+09  BROOKLYN
# 2         09/30/2024 11:32:09 AM        03 BRONX  2.029420e+09     BRONX
# 3         09/30/2024 12:00:00 AM       02 QUEENS  4.001310e+09    QUEENS
# 4         09/30/2024 11:33:21 AM       08 QUEENS  4.067970e+09    QUEENS
#
#   X Coordinate (State Plane) Y Coordinate (State Plane)  \
# 0                    979,188                    162,153
# 1                    982,393                    168,480
# 2                  1,013,229                    244,598
# 3                  1,008,211                    210,834
# 4                  1,036,658                    205,328
#
#   Open Data Channel Type Park Facility Name Park Borough Vehicle Type  \
# 0                UNKNOWN        Unspecified     BROOKLYN          NaN
# 1                UNKNOWN        Unspecified     BROOKLYN          NaN
# 2                UNKNOWN        Unspecified        BRONX          NaN
# 3                UNKNOWN        Unspecified       QUEENS          NaN
# 4                 ONLINE        Unspecified       QUEENS          NaN
#
#   Taxi Company Borough Taxi Pick Up Location Bridge Highway Name  \
# 0                  NaN                   NaN                 NaN
# 1                  NaN                   NaN                 NaN
# 2                  NaN                   NaN                 NaN
# 3                  NaN                   NaN                 NaN
# 4                  NaN                   NaN                 NaN
#
#   Bridge Highway Direction Road Ramp Bridge Highway Segment   Latitude  \
# 0                      NaN       NaN                    NaN  40.611747
# 1                      NaN       NaN                    NaN  40.629115
# 2                      NaN       NaN                    NaN  40.837993
# 3                      NaN       NaN                    NaN  40.745335
# 4                      NaN       NaN                    NaN  40.730099
#
#    Longitude                                  Location
# 0 -74.018232   (40.61174747150455, -74.01823172578321)
# 1 -74.006690  (40.629115019847006, -74.00669006815433)
# 2 -73.895272   (40.83799273965483, -73.89527182764397)
# 3 -73.913527     (40.74533475364905, -73.913526986578)
# 4 -73.810908   (40.73009934988612, -73.81090754397326)

# %% [markdown]
# Listing the columns against their indexes

# %%
count = 0
for col in df.columns:
  print(count, col)
  count+=1
# Out:
# 0 Unique Key
# 1 Created Date
# 2 Closed Date
# 3 Agency
# 4 Agency Name
# 5 Complaint Type
# 6 Descriptor
# 7 Location Type
# 8 Incident Zip
# 9 Incident Address
# 10 Street Name
# 11 Cross Street 1
# 12 Cross Street 2
# 13 Intersection Street 1
# 14 Intersection Street 2
# 15 Address Type
# 16 City
# 17 Landmark
# 18 Facility Type
# 19 Status
# 20 Due Date
# 21 Resolution Description
# 22 Resolution Action Updated Date
# 23 Community Board
# 24 BBL
# 25 Borough
# 26 X Coordinate (State Plane)
# 27 Y Coordinate (State Plane)
# 28 Open Data Channel Type
# 29 Park Facility Name
# 30 Park Borough
# 31 Vehicle Type
# 32 Taxi Company Borough
# 33 Taxi Pick Up Location
# 34 Bridge Highway Name
# 35 Bridge Highway Direction
# 36 Road Ramp
# 37 Bridge Highway Segment
# 38 Latitude
# 39 Longitude
# 40 Location

# %% [markdown]
# Dropping unnecessary columns to speed up data processing

# %%
df.drop(df.columns[[32,33,34,35]], axis = 1, inplace = True)

# %% [markdown]
# Checking the shape and dataframe after dropping the columns

# %%
print(df.shape)
df.head(5)
# Out:
# (12954036, 37)
#    Unique Key            Created Date             Closed Date Agency  \
# 0    62613972  09/30/2024 03:14:00 PM  09/29/2024 03:13:00 PM    DOT
# 1    62618855  09/30/2024 11:34:12 AM  09/30/2024 11:34:12 AM    DOB
# 2    62608311  09/30/2024 11:31:35 AM  09/30/2024 11:32:06 AM    DPR
# 3    62617195  09/30/2024 11:31:11 AM  09/30/2024 11:31:11 AM    DOB
# 4    62609038  09/30/2024 11:30:15 AM  09/30/2024 11:33:18 AM   NYPD
#
#                           Agency Name                 Complaint Type  \
# 0        Department of Transportation         Street Light Condition
# 1             Department of Buildings                   Building/Use
# 2  Department of Parks and Recreation        Maintenance or Facility
# 3             Department of Buildings  General Construction/Plumbing
# 4     New York City Police Department                  Drug Activity
#
#                                          Descriptor    Location Type  \
# 0                        Multiple St Lts Dayburning              NaN
# 1  Illegal Conversion Of Residential Building/Space              NaN
# 2                                 Garbage or Litter  Street/Curbside
# 3     Cons - Contrary/Beyond Approved Plans/Permits              NaN
# 4                                       Use Outside  Street/Sidewalk
#
#   Incident Zip         Incident Address        Street Name     Cross Street 1  \
# 0      11228.0         DYKER BEACH PARK   DYKER BEACH PARK             14 AVE
# 1      11219.0           1071 65 STREET          65 STREET                NaN
# 2      10457.0             CROTONA PARK       CROTONA PARK  CLAREMONT PARKWAY
# 3      11377.0          41-24 51 STREET          51 STREET                NaN
# 4      11365.0  71-01 PARSONS BOULEVARD  PARSONS BOULEVARD          71 AVENUE
#
#        Cross Street 2 Intersection Street 1 Intersection Street 2  \
# 0               7 AVE                   NaN                   NaN
# 1                 NaN                   NaN                   NaN
# 2  CROTONA PARK NORTH     CLAREMONT PARKWAY    CROTONA PARK NORTH
# 3                 NaN                   NaN                   NaN
# 4           72 AVENUE             71 AVENUE             72 AVENUE
#
#    Address Type           City           Landmark Facility Type   Status  \
# 0     PLACENAME       BROOKLYN                NaN           NaN  Pending
# 1       ADDRESS       BROOKLYN                NaN           NaN     Open
# 2  UNRECOGNIZED          BRONX       CROTONA PARK           NaN   Closed
# 3       ADDRESS       WOODSIDE                NaN           NaN     Open
# 4       ADDRESS  FRESH MEADOWS  PARSONS BOULEVARD           NaN   Closed
#
#   Due Date                             Resolution Description  \
# 0      NaN  Service Request status for this request is ava...
# 1      NaN  Your Service Request has been submitted to the...
# 2      NaN  NYC Parks has completed the requested work ord...
# 3      NaN  Your Service Request has been submitted to the...
# 4      NaN  The Police Department responded to the complai...
#
#   Resolution Action Updated Date Community Board           BBL   Borough  \
# 0         09/29/2024 03:13:00 PM     10 BROOKLYN  3.064180e+09  BROOKLYN
# 1         09/30/2024 12:00:00 AM     10 BROOKLYN  3.057440e+09  BROOKLYN
# 2         09/30/2024 11:32:09 AM        03 BRONX  2.029420e+09     BRONX
# 3         09/30/2024 12:00:00 AM       02 QUEENS  4.001310e+09    QUEENS
# 4         09/30/2024 11:33:21 AM       08 QUEENS  4.067970e+09    QUEENS
#
#   X Coordinate (State Plane) Y Coordinate (State Plane)  \
# 0                    979,188                    162,153
# 1                    982,393                    168,480
# 2                  1,013,229                    244,598
# 3                  1,008,211                    210,834
# 4                  1,036,658                    205,328
#
#   Open Data Channel Type Park Facility Name Park Borough Vehicle Type  \
# 0                UNKNOWN        Unspecified     BROOKLYN          NaN
# 1                UNKNOWN        Unspecified     BROOKLYN          NaN
# 2                UNKNOWN        Unspecified        BRONX          NaN
# 3                UNKNOWN        Unspecified       QUEENS          NaN
# 4                 ONLINE        Unspecified       QUEENS          NaN
#
#   Road Ramp Bridge Highway Segment   Latitude  Longitude  \
# 0       NaN                    NaN  40.611747 -74.018232
# 1       NaN                    NaN  40.629115 -74.006690
# 2       NaN                    NaN  40.837993 -73.895272
# 3       NaN                    NaN  40.745335 -73.913527
# 4       NaN                    NaN  40.730099 -73.810908
#
#                                    Location
# 0   (40.61174747150455, -74.01823172578321)
# 1  (40.629115019847006, -74.00669006815433)
# 2   (40.83799273965483, -73.89527182764397)
# 3     (40.74533475364905, -73.913526986578)
# 4   (40.73009934988612, -73.81090754397326)

# %% [markdown]
# Checking for nulls

# %%
null_counts = df.isnull().sum()
print(null_counts)
# Out:
# Unique Key                               0
# Created Date                             0
# Closed Date                              0
# Agency                                   0
# Agency Name                              0
# Complaint Type                           0
# Descriptor                          347100
# Location Type                      1721570
# Incident Zip                        200204
# Incident Address                    559496
# Street Name                         559940
# Cross Street 1                     3636778
# Cross Street 2                     3638152
# Intersection Street 1              4728236
# Intersection Street 2              4722683
# Address Type                       1723433
# City                                677879
# Landmark                           5708774
# Facility Type                     12796374
# Status                                   0
# Due Date                          12890922
# Resolution Description              469689
# Resolution Action Updated Date       17360
# Community Board                      18722
# BBL                                1519834
# Borough                              18722
# X Coordinate (State Plane)          242114
# Y Coordinate (State Plane)          240962
# Open Data Channel Type                   0
# Park Facility Name                    8251
# Park Borough                         18722
# Vehicle Type                      12810025
# Road Ramp                         12926155
# Bridge Highway Segment            12871158
# Latitude                            242238
# Longitude                           242238
# Location                            242238
# dtype: int64

# %% [markdown]
# Checking datatypes

# %%
print(df.dtypes)
# Out:
# Unique Key                          int64
# Created Date                       object
# Closed Date                        object
# Agency                             object
# Agency Name                        object
# Complaint Type                     object
# Descriptor                         object
# Location Type                      object
# Incident Zip                       object
# Incident Address                   object
# Street Name                        object
# Cross Street 1                     object
# Cross Street 2                     object
# Intersection Street 1              object
# Intersection Street 2              object
# Address Type                       object
# City                               object
# Landmark                           object
# Facility Type                      object
# Status                             object
# Due Date                           object
# Resolution Description             object
# Resolution Action Updated Date     object
# Community Board                    object
# BBL                               float64
# Borough                            object
# X Coordinate (State Plane)         object
# Y Coordinate (State Plane)         object
# Open Data Channel Type             object
# Park Facility Name                 object
# Park Borough                       object
# Vehicle Type                       object
# Road Ramp                          object
# Bridge Highway Segment             object
# Latitude                          float64
# Longitude                         float64
# Location                           object
# dtype: object

# %% [markdown]
# Converting datatypes for datetimes columns from object to datetime

# %%
df['Closed Date']= pd.to_datetime(df['Closed Date'])
df['Created Date']= pd.to_datetime(df['Created Date'])
# Out:
# C:\Users\z004ymcy\AppData\Local\Temp\ipykernel_5908\2544357372.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Closed Date']= pd.to_datetime(df['Closed Date'])
# C:\Users\z004ymcy\AppData\Local\Temp\ipykernel_5908\2544357372.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Created Date']= pd.to_datetime(df['Created Date'])

# %% [markdown]
# Calculating Resolution Time and adding it to the dataframe

# %%
df['Resolution_Time'] = (df['Closed Date'] - df['Created Date']).dt.days

# %% [markdown]
# Applying data sanity checks

# %%
df = df[df['Resolution_Time'].notnull()]
df = df[df['Closed Date'] >= df['Created Date']]

# %% [markdown]
# Creating new columns for day/week/ month/ year of the creation date

# %%
df['Day of Week'] = df['Created Date'].dt.dayofweek
df['Day of Month'] = df['Created Date'].dt.day
df['Month'] = df['Created Date'].dt.month
df['Year'] = df['Created Date'].dt.year

# %% [markdown]
# Checking the final data types

# %%
df.dtypes
# Out:
# Unique Key                                 int64
# Created Date                      datetime64[ns]
# Closed Date                       datetime64[ns]
# Agency                                    object
# Agency Name                               object
# Complaint Type                            object
# Descriptor                                object
# Location Type                             object
# Incident Zip                              object
# Incident Address                          object
# Street Name                               object
# Cross Street 1                            object
# Cross Street 2                            object
# Intersection Street 1                     object
# Intersection Street 2                     object
# Address Type                              object
# City                                      object
# Landmark                                  object
# Facility Type                             object
# Status                                    object
# Due Date                                  object
# Resolution Description                    object
# Resolution Action Updated Date            object
# Community Board                           object
# BBL                                      float64
# Borough                                   object
# X Coordinate (State Plane)                object
# Y Coordinate (State Plane)                object
# Open Data Channel Type                    object
# Park Facility Name                        object
# Park Borough                              object
# Vehicle Type                              object
# Road Ramp                                 object
# Bridge Highway Segment                    object
# Latitude                                 float64
# Longitude                                float64
# Location                                  object
# Resolution_Time                            int64
# Day of Week                                int32
# Day of Month                               int32
# Month                                      int32
# Year                                       int32
# dtype: object

# %% [markdown]
# ## Loading the Storms Dataset

# %% [markdown]
# Loading the dataset for Bronx

# %%
df_storm_bronx = pd.read_csv('storm_data_search_results_bronx.csv', 
                       header = 0,
                       sep = ',', 
                       parse_dates = ['BEGIN_DATE'],
                       index_col = 'EVENT_ID')
print(df_storm_bronx.shape)
# Out:
# (39, 38)

# %% [markdown]
# Loading the dataset for Manhattan

# %%
df_storm_ny = pd.read_csv('storm_data_search_results_ny.csv', 
                       header = 0,
                       sep = ',', 
                       parse_dates = ['BEGIN_DATE'],
                       index_col = 'EVENT_ID')
print(df_storm_ny.shape)
# Out:
# (38, 38)

# %% [markdown]
# Loading the dataset for Queens

# %%
df_storm_queens = pd.read_csv('storm_data_search_results_queens.csv', 
                       header = 0,
                       sep = ',', 
                       parse_dates = ['BEGIN_DATE'],
                       index_col = 'EVENT_ID')
print(df_storm_queens.shape)
# Out:
# (100, 38)

# %% [markdown]
# ## Preprocessing the Storms Data

# %% [markdown]
# Appending the datasets

# %%
df_storm = pd.concat([df_storm_ny, df_storm_bronx, df_storm_queens], ignore_index=True)
df_storm.shape
# Out:
# (177, 38)

# %% [markdown]
# Checking the loaded data

# %%
pd.set_option('display.max_columns', None)
df_storm.head(5)
# Out:
#                    CZ_NAME_STR BEGIN_LOCATION BEGIN_DATE  BEGIN_TIME  \
# 0  NEW YORK (MANHATTAN) (ZONE)                2020-11-02        1200
# 1                 NEW YORK CO.       NEW YORK 2020-11-15        2035
# 2                 NEW YORK CO.   CENTRAL PARK 2020-11-15        2035
# 3  NEW YORK (MANHATTAN) (ZONE)                2020-12-16        1600
# 4  NEW YORK (MANHATTAN) (ZONE)                2021-01-29        1300
#
#           EVENT_TYPE MAGNITUDE TOR_F_SCALE  DEATHS_DIRECT  INJURIES_DIRECT  \
# 0          High Wind     35.00                          0                0
# 1  Thunderstorm Wind     61.00                          0                0
# 2  Thunderstorm Wind     52.00                          0                0
# 3       Winter Storm                                    0                0
# 4          High Wind     36.00                          0                0
#
#    DAMAGE_PROPERTY_NUM  DAMAGE_CROPS_NUM STATE_ABBR CZ_TIMEZONE  \
# 0                    0                 0         NY       EST-5
# 1                 5000                 0         NY       EST-5
# 2                 4000                 0         NY       EST-5
# 3                    0                 0         NY       EST-5
# 4                    0                 0         NY       EST-5
#
#   MAGNITUDE_TYPE  EPISODE_ID CZ_TYPE  CZ_FIPS  WFO  INJURIES_INDIRECT  \
# 0             MS      154487       Z       72  OKX                  0
# 1             EG      154092       C       61  OKX                  0
# 2             EG      154092       C       61  OKX                  0
# 3                     155048       Z       72  OKX                  0
# 4             MS      155495       Z       72  OKX                  0
#
#    DEATHS_INDIRECT                     SOURCE FLOOD_CAUSE TOR_LENGTH  \
# 0                0                    Mesonet
# 1                0            Broadcast Media
# 2                0            Broadcast Media
# 3                0  Official NWS Observations
# 4                0                    Mesonet
#
#   TOR_WIDTH BEGIN_RANGE BEGIN_AZIMUTH END_RANGE END_AZIMUTH  END_LOCATION  \
# 0
# 1                     1             N         1           N      NEW YORK
# 2                     5             N         5           N  CENTRAL PARK
# 3
# 4
#
#      END_DATE  END_TIME BEGIN_LAT BEGIN_LON  END_LAT   END_LON  \
# 0  11/02/2020      1300
# 1  11/15/2020      2035   40.7411  -73.9979  40.7411  -73.9979
# 2  11/15/2020      2035   40.8481  -73.9348  40.8481  -73.9348
# 3  12/17/2020      1200
# 4  01/29/2021      1400
#
#                                      EVENT_NARRATIVE  \
# 0  A sustained wind of 40 mph was recorded at Was...
# 1  Downed scaffolding at 18th Street and Seventh ...
# 2  Downed scaffolding at West 179th Street and St...
# 3  The Official NWS Observation at Central Park, ...
# 4  A measured wind gust of 41 mph was recorded in...
#
#                                    EPISODE_NARRATIVE  ABSOLUTE_ROWNUMBER
# 0  The pressure gradient behind the passage of a ...                   1
# 1  A strong cold front triggered convective showe...                   2
# 2  A strong cold front triggered convective showe...                   3
# 3  Low pressure developed along the Middle Atlant...                   4
# 4  High winds occurred over the region as high pr...                   5

# %% [markdown]
# Listing the columns against their indexes

# %%
count = 0
for col in df_storm.columns:
  print(count, col)
  count+=1
# Out:
# 0 CZ_NAME_STR
# 1 BEGIN_LOCATION
# 2 BEGIN_DATE
# 3 BEGIN_TIME
# 4 EVENT_TYPE
# 5 MAGNITUDE
# 6 TOR_F_SCALE
# 7 DEATHS_DIRECT
# 8 INJURIES_DIRECT
# 9 DAMAGE_PROPERTY_NUM
# 10 DAMAGE_CROPS_NUM
# 11 STATE_ABBR
# 12 CZ_TIMEZONE
# 13 MAGNITUDE_TYPE
# 14 EPISODE_ID
# 15 CZ_TYPE
# 16 CZ_FIPS
# 17 WFO
# 18 INJURIES_INDIRECT
# 19 DEATHS_INDIRECT
# 20 SOURCE
# 21 FLOOD_CAUSE
# 22 TOR_LENGTH
# 23 TOR_WIDTH
# 24 BEGIN_RANGE
# 25 BEGIN_AZIMUTH
# 26 END_RANGE
# 27 END_AZIMUTH
# 28 END_LOCATION
# 29 END_DATE
# 30 END_TIME
# 31 BEGIN_LAT
# 32 BEGIN_LON
# 33 END_LAT
# 34 END_LON
# 35 EVENT_NARRATIVE
# 36 EPISODE_NARRATIVE
# 37 ABSOLUTE_ROWNUMBER

# %% [markdown]
# Checking for nulls

# %%
null_counts = df_storm.isnull().sum()
print(null_counts)
# Out:
# CZ_NAME_STR            0
# BEGIN_LOCATION         0
# BEGIN_DATE             0
# BEGIN_TIME             0
# EVENT_TYPE             0
# MAGNITUDE              0
# TOR_F_SCALE            0
# DEATHS_DIRECT          0
# INJURIES_DIRECT        0
# DAMAGE_PROPERTY_NUM    0
# DAMAGE_CROPS_NUM       0
# STATE_ABBR             0
# CZ_TIMEZONE            0
# MAGNITUDE_TYPE         0
# EPISODE_ID             0
# CZ_TYPE                0
# CZ_FIPS                0
# WFO                    0
# INJURIES_INDIRECT      0
# DEATHS_INDIRECT        0
# SOURCE                 0
# FLOOD_CAUSE            0
# TOR_LENGTH             0
# TOR_WIDTH              0
# BEGIN_RANGE            0
# BEGIN_AZIMUTH          0
# END_RANGE              0
# END_AZIMUTH            0
# END_LOCATION           0
# END_DATE               0
# END_TIME               0
# BEGIN_LAT              0
# BEGIN_LON              0
# END_LAT                0
# END_LON                0
# EVENT_NARRATIVE        0
# EPISODE_NARRATIVE      0
# ABSOLUTE_ROWNUMBER     0
# dtype: int64

# %% [markdown]
# Checking datatypes

# %%
print(df_storm.dtypes)
# Out:
# CZ_NAME_STR                    object
# BEGIN_LOCATION                 object
# BEGIN_DATE             datetime64[ns]
# BEGIN_TIME                      int64
# EVENT_TYPE                     object
# MAGNITUDE                      object
# TOR_F_SCALE                    object
# DEATHS_DIRECT                   int64
# INJURIES_DIRECT                 int64
# DAMAGE_PROPERTY_NUM             int64
# DAMAGE_CROPS_NUM                int64
# STATE_ABBR                     object
# CZ_TIMEZONE                    object
# MAGNITUDE_TYPE                 object
# EPISODE_ID                      int64
# CZ_TYPE                        object
# CZ_FIPS                         int64
# WFO                            object
# INJURIES_INDIRECT               int64
# DEATHS_INDIRECT                 int64
# SOURCE                         object
# FLOOD_CAUSE                    object
# TOR_LENGTH                     object
# TOR_WIDTH                      object
# BEGIN_RANGE                    object
# BEGIN_AZIMUTH                  object
# END_RANGE                      object
# END_AZIMUTH                    object
# END_LOCATION                   object
# END_DATE                       object
# END_TIME                        int64
# BEGIN_LAT                      object
# BEGIN_LON                      object
# END_LAT                        object
# END_LON                        object
# EVENT_NARRATIVE                object
# EPISODE_NARRATIVE              object
# ABSOLUTE_ROWNUMBER              int64
# dtype: object

# %% [markdown]
# Renaming columns for better understanding and easier merge

# %%
df_storm = df_storm.rename(columns={'BEGIN_DATE': 'Created Date', 'CZ_NAME_STR': 'Storm_Borough'})

# %% [markdown]
# ## Merging the Datasets

# %%
result = pd.merge(df,df_storm[['Storm_Borough','Created Date','BEGIN_TIME','EVENT_TYPE']], on = 'Created Date', how = 'left')
result.shape
# Out:
# (12924144, 45)

# %%
result.to_csv('final_dataset.csv', index=False)
